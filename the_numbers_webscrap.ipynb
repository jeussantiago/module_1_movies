# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
#turns an encoded title into readable english
def decode(title_encoded):
    #encoded meanings
    attr = {"â\x99": "'", "â\x80\x94": "-" }
    #replace the decoded portions
    title = title_encoded.replace("â\x99", "'").replace("â\x80\x94", "-" )
    return title

# %%
#returns the full title of the movie
def get_movie_title(soup):
    #go to title section in html
    title_info = soup.find("h1")
    #get the title - weird characters, encoded
    title_encoded = title_info.get_text()[:-7]
    #decode the title to english
    title = decode(title_encoded)
    return title
    
# title = get_movie_title(soup)
# title

# %%
#goes to movie page - returns the movie budget
def get_movie_budget(soup):
    
    #go to table with info
    movie_info = soup.find_all('table')
    #there are multiple tables on page - some movies dont have a budget listed
    #go to table with has budget - get to html line with that info - get it
    try:
        movie_budget = movie_info[3].find("td").next_sibling.get_text()
    except:
        movie_budget = None
    return movie_budget



# bud = get_movie_budget(soup)
# print(bud)

# %%
#takes in section of one movie at a time
#returns a tuple with the of the movie (rank_in_year, year, movie_name, Genre, Gross, Budget)
def movie_info(web, movie_stats, year):
    #go to section where nexcessary information is - take it
    data = movie_stats.find_all('td', class_='data')
    #get the rank and gross of movie
    movie_rank = data[0].get_text()
    movie_gross = data[1].get_text()
    #go to section where info is
    link_data = movie_stats.find_all('a')
    #get and genre
    movie_genre = link_data[-1].get_text()
    #get the suffix for the link where the movie budget is
    movie_info_link_suf = link_data[0]['href']
    #create the link to go into the movie page to grab the budget
    movie_url = "{}{}".format(web, movie_info_link_suf)

    #get the page with the full name and budget
    r = requests.get(movie_url)
    c = r.content
    soup = BeautifulSoup(c, 'html.parser')
    #get movie budget and title
    movie_budget = get_movie_budget(soup)
    movie_title = get_movie_title(soup)

    #return the tuple with movie information

    return (movie_rank, movie_title, year, movie_genre, movie_gross, movie_budget)

    
#movie_info(web, movie_stats_lst[1], 2018)

# %%
#get infos of top movie in that year
def movies_of_year(web, year):
    #create url for year
    url = "{}/market/{}/top-grossing-movies".format(web, year)
    r = requests.get(url)
    c = r.content
    soup = BeautifulSoup(c, 'html.parser')
    #get to where the table information is
    movie_table = soup.find("table")
    movie_stats_lst = movie_table.find_all("tr")
    all_movies_year_stats = []
    #2019 year doesn't have many movies listed yet
    num_movies = list(range(1,501))
    if year == 2019:
        num_movies = list(range(1,191))
    
    #iterate through the table of movies, ignore the first one - i = rank
    for i in num_movies:
        #get the information of the movie 
        movie_stat = movie_info(web, movie_stats_lst[i], year)
        #append that information to a list
        all_movies_year_stats.append(movie_stat)
    #return a list of tuples with each tuple containing a movie info
    return all_movies_year_stats

# web = "https://www.the-numbers.com"
# test = movies_of_year(web, 2019)

# %%
#returns dictionary with key=year, value=list of movies info
def movies_of_years():
    web = "https://www.the-numbers.com"
    #crete dict with each year as key
    year_movies = {}
    #go through the years
    for year in range(2019, 2014, -1):
        #print(year)
        #go to page with top movies in year
        all_movies = movies_of_year(web, year)
        #attach to dict
        year_movies[year] = all_movies
    
    return year_movies
        
year_movies = movies_of_years()

# %%
year_movies[2019]
# Out:
# [('1', 'Captain Marvel', 2019, 'Action', '$323,646,033', '$152,000,000'),
#  ('2',
#   'How to Train Your Dragon: The Hidden World',
#   2019,
#   'Adventure',
#   '$147,460,290',
#   '$129,000,000'),
#  ('3', 'Glass', 2019, 'Thriller/Suspense', '$110,861,630', '$20,000,000'),
#  ('4', 'The Upside', 2019, 'Comedy', '$106,984,792', '$37,500,000'),
#  ('5',
#   'The LEGO Movie 2: The Second Part',
#   2019,
#   'Adventure',
#   '$103,762,494',
#   '$99,000,000'),
#  ('6', 'Us', 2019, 'Thriller/Suspense', '$85,106,185', '$24,600,000'),
#  ('7', 'Alita: Battle Angel', 2019, 'Action', '$83,956,461', None),
#  ('8', 'Aquaman', 2019, 'Action', '$74,802,530', '$160,000,000'),
#  ('9',
#   "Tyler Perry's A Madea Family Funeral",
#   2019,
#   'Comedy',
#   '$66,688,573',
#   None),
#  ('10',
#   'Spider-Man: Into The Spider-Verse 3D',
#   2019,
#   'Adventure',
#   '$55,923,345',
#   '$90,000,000'),
#  ('11', 'Bumblebee', 2019, 'Adventure', '$55,769,470', '$102,000,000'),
#  ('12', 'What Men Want', 2019, 'Comedy', '$54,085,444', '$20,000,000'),
#  ('13', 'Green Book', 2019, 'Comedy', '$48,837,730', '$28,900,000'),
#  ('14',
#   "Isn't it Romantic",
#   2019,
#   'Romantic Comedy',
#   '$47,691,683',
#   '$31,000,000'),
#  ('15', "A Dog's Way Home", 2019, 'Drama', '$41,952,715', None),
#  ('16', 'The Mule', 2019, 'Drama', '$39,084,073', '$50,000,000'),
#  ('17', 'Escape Room', 2019, 'Thriller/Suspense', '$38,467,985', None),
#  ('18',
#   'Mary Poppins Returns',
#   2019,
#   'Musical',
#   '$33,014,229',
#   '$130,000,000'),
#  ('19', 'Cold Pursuit', 2019, 'Thriller/Suspense', '$31,854,994', None),
#  ('20',
#   'Dragon Ball Super: Broly',
#   2019,
#   'Action',
#   '$30,376,755',
#   '$8,500,000'),
#  ('21', 'Wonder Park', 2019, 'Adventure', '$30,049,734', '$100,000,000'),
#  ('22', 'Five Feet Apart', 2019, 'Drama', '$28,145,448', '$7,000,000'),
#  ('23',
#   'Happy Death Day 2U',
#   2019,
#   'Thriller/Suspense',
#   '$27,892,355',
#   '$9,000,000'),
#  ('24', 'Bohemian Rhapsody', 2019, 'Drama', '$26,143,592', '$55,000,000'),
#  ('25',
#   'Fighting With My Family',
#   2019,
#   'Comedy',
#   '$22,028,635',
#   '$11,000,000'),
#  ('26', 'On the Basis of Sex', 2019, 'Drama', '$20,914,838', '$20,000,000'),
#  ('27', 'The Favourite', 2019, 'Black Comedy', '$18,267,686', '$15,000,000'),
#  ('28', 'Vice', 2019, 'Black Comedy', '$18,093,238', '$60,000,000'),
#  ('29',
#   'The Kid Who Would Be King',
#   2019,
#   'Adventure',
#   '$16,780,002',
#   '$59,000,000'),
#  ('30', 'Miss Bala', 2019, 'Action', '$14,998,027', '$15,000,000'),
#  ('31', 'The Prodigy', 2019, 'Horror', '$14,827,206', '$6,000,000'),
#  ('32',
#   'Ralph Breaks The Internet',
#   2019,
#   'Adventure',
#   '$13,827,567',
#   '$175,000,000'),
#  ('33', 'A Star is Born', 2019, 'Drama', '$13,141,994', '$36,000,000'),
#  ('34', 'They Shall Not Grow Old', 2019, 'Documentary', '$11,965,907', None),
#  ('35',
#   'If Beale Street Could Talk',
#   2019,
#   'Drama',
#   '$10,477,647',
#   '$12,000,000'),
#  ('36', 'Greta', 2019, 'Thriller/Suspense', '$10,460,680', None),
#  ('37', 'Serenity', 2019, 'Thriller/Suspense', '$8,547,045', '$25,000,000'),
#  ('38', 'No Manches Frida 2', 2019, 'Comedy', '$6,939,206', None),
#  ('39', 'Apollo 11', 2019, 'Documentary', '$6,857,086', None),
#  ('40', 'Second Act', 2019, 'Comedy', '$6,489,861', '$15,700,000'),
#  ('41', 'Run the Race', 2019, 'Drama', '$6,196,031', None),
#  ('42', 'Free Solo', 2019, 'Documentary', '$5,996,366', None),
#  ('43',
#   'Captive State',
#   2019,
#   'Thriller/Suspense',
#   '$5,582,120',
#   '$25,000,000'),
#  ('44', 'Stan & Ollie', 2019, 'Drama', '$5,157,885', None),
#  ('45', 'Zimna wojna', 2019, 'Drama', '$4,285,825', None),
#  ('46', 'Gully Boy', 2019, 'Adventure', '$4,216,437', None),
#  ('47', 'Uri: The Surgical Strike', 2019, 'Action', '$4,185,663', None),
#  ('48', 'Replicas', 2019, 'Thriller/Suspense', '$4,046,429', None),
#  ('49', '2019 Oscar Shorts', 2019, 'Multiple Genres', '$3,530,255', None),
#  ('50', 'Creed II', 2019, 'Drama', '$3,267,369', '$50,000,000'),
#  ('51', 'Mary Queen of Scots', 2019, 'Drama', '$3,043,614', '$25,000,000'),
#  ('52',
#   'Fantastic Beasts: The Crimes of Grindelwald',
#   2019,
#   'Adventure',
#   '$2,774,042',
#   '$200,000,000'),
#  ('53', 'Gloria Bell', 2019, 'Drama', '$2,750,917', None),
#  ('54', 'Todos lo saben', 2019, 'Drama', '$2,580,695', None),
#  ('55', 'Instant Family', 2019, 'Comedy', '$2,518,231', '$48,000,000'),
#  ('56', 'Holmes & Watson', 2019, 'Comedy', '$2,254,994', '$42,000,000'),
#  ('57', 'Arctic', 2019, 'Drama', '$2,251,036', None),
#  ('58', 'Total Dhamaal', 2019, 'Comedy', '$2,167,632', None),
#  ('59', 'Manbiki kazoku', 2019, 'Drama', '$1,624,097', None),
#  ('60', 'CafarnaÃºm', 2019, 'Drama', '$1,392,421', None),
#  ('61', 'The Kid', 2019, 'Western', '$1,376,796', None),
#  ('62', 'The Wife', 2019, 'Drama', '$1,373,986', None),
#  ('63', 'Badla', 2019, 'Thriller/Suspense', '$1,313,740', None),
#  ('64', 'Destroyer', 2019, 'Thriller/Suspense', '$1,285,243', '$9,000,000'),
#  ('65', 'Can You Ever Forgive Me?', 2019, 'Drama', '$1,259,896', None),
#  ('66', 'Ben is Back', 2019, 'Drama', '$1,191,342', None),
#  ('67',
#   'Ek Ladki Ko Dekhah Toh Aisa Laga',
#   2019,
#   'Romantic Comedy',
#   '$1,182,636',
#   None),
#  ('68',
#   'Werk ohne Autor',
#   2019,
#   'Thriller/Suspense',
#   '$1,076,261',
#   '$1,400,000'),
#  ('69', 'Perfectos desconocidos', 2019, 'Comedy', '$1,014,507', None),
#  ('70', "Dr. Seuss' The Grinch", 2019, 'Adventure', '$998,820', '$75,000,000'),
#  ('71', 'Simmba', 2019, 'Action', '$986,339', None),
#  ('72',
#   'JONI 75: A Birthday Celebration',
#   2019,
#   'Concert/Performance',
#   '$751,119',
#   None),
#  ('73', 'Climax', 2019, 'Drama', '$748,937', None),
#  ('74',
#   'BlacKkKlansman',
#   2019,
#   'Thriller/Suspense',
#   '$747,775',
#   '$15,000,000'),
#  ('75', 'Hai Phuong', 2019, 'Action', '$578,423', None),
#  ('76',
#   'Bi Bei Shang Geng Bei Shang De Gu Shi',
#   2019,
#   'Drama',
#   '$503,584',
#   None),
#  ('77', 'Widows', 2019, 'Thriller/Suspense', '$498,459', '$40,000,000'),
#  ('78', 'PÃ¡jaros de verano', 2019, 'Drama', '$445,926', None),
#  ('79', 'Transit', 2019, 'Drama', '$390,078', None),
#  ('80', 'The Mustang', 2019, 'Drama', '$363,780', None),
#  ('81', 'CatVideoFest', 2019, 'Oscilloscope Pict…', '$361,730', None),
#  ('82', 'Welcome to Marwen', 2019, 'Drama', '$356,895', '$45,000,000'),
#  ('83', 'The Wedding Guest', 2019, 'Thriller/Suspense', '$328,729', None),
#  ('84', 'Cruel Intentions', 2019, 'Drama', '$323,323', '$11,000,000'),
#  ('85', 'Die Unsichtbaren', 2019, 'Documentary', '$319,929', None),
#  ('86', "At Eternity's Gate", 2019, 'Drama', '$317,975', None),
#  ('87',
#   'Josh Groban Bridges from Madison Square Garden',
#   2019,
#   'Concert/Performance',
#   '$315,173',
#   None),
#  ('88', 'Smallfoot', 2019, 'Adventure', '$263,482', '$80,000,000'),
#  ('89', 'Lords of Chaos', 2019, 'Thriller/Suspense', '$252,245', None),
#  ('90', 'Canal Street', 2019, 'Drama', '$251,917', None),
#  ('91',
#   '311: Enlarged to Show Detail 3',
#   2019,
#   'Concert/Performance',
#   '$238,211',
#   None),
#  ('92', 'Kona fer Ã\xad strÃ\xadÃ°', 2019, 'Action', '$230,660', None),
#  ('93', 'The Aftermath', 2019, 'Drama', '$210,977', None),
#  ('94', 'The Iron Orchard', 2019, 'Drama', '$197,991', None),
#  ('95', 'Mortal Engines', 2019, 'Action', '$183,315', '$100,000,000'),
#  ('96', 'Robin Hood', 2019, 'Action', '$179,615', '$99,000,000'),
#  ('97',
#   'Ponokku tanpen gekijÃ´: Chiisa na eiyÃ»-Kani to tamago to tÃ´mei ningen',
#   2019,
#   'Adventure',
#   '$178,027',
#   None),
#  ('98', 'To Dust', 2019, 'Drama', '$173,242', None),
#  ('99',
#   'The Possession of Hannah Grace',
#   2019,
#   'Horror',
#   '$153,478',
#   '$6,000,000'),
#  ('100', 'Xiao zhu pei qi guo da nian', 2019, 'Adventure', '$131,225', None),
#  ('101', 'The Last Resort', 2019, 'Documentary', '$129,947', None),
#  ('102', 'The World Before Your Feet', 2019, 'Documentary', '$122,542', None),
#  ('103', 'Who Will Write Our History', 2019, 'Documentary', '$117,447', None),
#  ('104', 'The Hummingbird Project', 2019, 'Drama', '$112,532', None),
#  ('105', 'Faith, Hope & Love', 2019, 'Romantic Comedy', '$103,764', None),
#  ('106', 'Beoning', 2019, 'Thriller/Suspense', '$101,279', None),
#  ('107', 'Ruben Brandt, a gyujto', 2019, 'Drama', '$98,844', None),
#  ('108',
#   'Ging chaat goo si/Ging chaat goo si juk jaap',
#   2019,
#   'Action',
#   '$97,181',
#   None),
#  ('109', "Le Livre D'Image", 2019, 'Drama', '$91,924', None),
#  ('110', 'Mirai no Mirai', 2019, 'Adventure', '$90,193', None),
#  ('111', 'Hotel Mumbai', 2019, 'Thriller/Suspense', '$88,065', None),
#  ('112', 'Sonchiriya', 2019, 'Action', '$86,765', None),
#  ('113', 'Venom', 2019, 'Action', '$82,267', '$116,000,000'),
#  ('114', 'Deadpool 2', 2019, 'Action', '$78,961', '$110,000,000'),
#  ('115', 'The Old Man and the Gun', 2019, 'Comedy', '$78,577', None),
#  ('116', 'Triple Threat', 2019, 'Thriller/Suspense', '$73,409', None),
#  ('117',
#   'The Nutcracker and the Four Realms',
#   2019,
#   'Adventure',
#   '$73,093',
#   '$132,900,000'),
#  ('118',
#   'Hale County This Morning, This Evening',
#   2019,
#   'Documentary',
#   '$69,045',
#   None),
#  ('119', 'Las Herederas', 2019, 'Drama', '$65,053', None),
#  ('120', 'Babylon', 2019, 'Drama', '$57,568', None),
#  ('121', 'Yun Nan Chong Gu Yunnan Valley', 2019, 'Action', '$50,933', None),
#  ('122', 'The Hate U Give', 2019, 'Drama', '$50,839', '$23,000,000'),
#  ('123', 'The Bounty Killer', 2019, 'Western', '$48,815', None),
#  ('124', 'Styx', 2019, 'Drama', '$47,762', None),
#  ('125', 'Voyna i mir', 2019, 'Continental Distr…', '$46,286', None),
#  ('126', 'Unga Astrid', 2019, 'Drama', '$43,076', None),
#  ('127', 'What is Democracy', 2019, 'Documentary', '$40,222', None),
#  ('128', 'Saint Judy', 2019, 'Drama', '$39,275', None),
#  ('129', 'Yardie', 2019, 'Drama', '$35,632', None),
#  ('130', 'Maria by Callas', 2019, 'Documentary', '$34,017', None),
#  ('131', 'Se Rokh', 2019, 'Drama', '$33,505', None),
#  ('132', 'An Acceptable Loss', 2019, 'Thriller/Suspense', '$32,452', None),
#  ('133',
#   'Horn From the Heart: The Paul Butterfield Story',
#   2019,
#   'Documentary',
#   '$30,179',
#   None),
#  ('134',
#   'Anthropocene: The Human Epoch',
#   2019,
#   'Documentary',
#   '$28,724',
#   None),
#  ('135', 'Ahlat Agaci', 2019, 'Drama', '$27,719', None),
#  ('136', 'Donnybrook', 2019, 'Drama', '$26,284', None),
#  ('137', 'Seuwingkizeu', 2019, 'Drama', '$26,244', None),
#  ('138', 'Le Retour du HÃ©ros', 2019, 'Drama', '$25,004', None),
#  ('139', 'La religieuse', 2019, 'Drama', '$23,972', None),
#  ('140', 'Beautiful Boy', 2019, 'Drama', '$23,952', '$25,000,000'),
#  ('141', 'Le Semeur', 2019, 'Drama', '$23,255', None),
#  ('142', 'Wrestle', 2019, 'Documentary', '$23,071', None),
#  ('143', 'Hotel by the River', 2019, 'Drama', '$22,232', None),
#  ('144', 'Plaire, aimer et courir vite', 2019, 'Drama', '$21,440', None),
#  ('145', 'The Hole in the Ground', 2019, 'Horror', '$21,072', None),
#  ('146', 'The Gospel of Eureka', 2019, 'Documentary', '$18,717', None),
#  ('147',
#   'Joseph Pulitzer: Voice of the People',
#   2019,
#   'Documentary',
#   '$16,971',
#   None),
#  ('148', 'Piercing', 2019, 'Horror', '$15,856', None),
#  ('149', 'NapszÃ¡llta', 2019, 'Drama', '$13,846', None),
#  ('150', 'Touch Me Not', 2019, 'Documentary', '$13,782', None),
#  ('151',
#   'Crazy Rich Asians',
#   2019,
#   'Romantic Comedy',
#   '$13,586',
#   '$30,000,000'),
#  ('152', 'Giant Little Ones', 2019, 'Drama', '$13,500', None),
#  ('153', 'Virginia Minnesota', 2019, 'Comedy', '$13,374', None),
#  ('154', 'Combat Obscura', 2019, 'Documentary', '$12,689', None),
#  ('155',
#   'Un couteau dans le coeur',
#   2019,
#   'Thriller/Suspense',
#   '$11,867',
#   None),
#  ('156', 'Out of Blue', 2019, 'Drama', '$11,719', None),
#  ('157', 'A Private War', 2019, 'Drama', '$10,098', None),
#  ('158', 'Studio 54', 2019, 'Documentary', '$9,355', None),
#  ('159', 'Tyrel', 2019, 'Drama', '$9,314', None),
#  ('160', 'The Aspern Papers', 2019, 'Drama', '$9,277', None),
#  ('161',
#   'The House That Jack Built',
#   2019,
#   'Thriller/Suspense',
#   '$7,213',
#   None),
#  ('162', 'The Eyes of Orson Welles', 2019, 'Documentary', '$6,999', None),
#  ('163', 'Life & Nothing More', 2019, 'Drama', '$6,745', None),
#  ('164', 'Under the Eiffel Tower', 2019, 'Romantic Comedy', '$6,291', None),
#  ('165', 'Ferrante Fever', 2019, 'Documentary', '$6,145', None),
#  ('166', 'The Charmer', 2019, 'Thriller/Suspense', '$6,118', None),
#  ('167', 'Monrovia, Indiana', 2019, 'Documentary', '$5,738', None),
#  ('168', 'Off Season', 2019, 'Thriller/Suspense', '$5,688', None),
#  ('169', 'Kinder des Kalifats', 2019, 'Documentary', '$5,643', None),
#  ('170', 'Liyana', 2019, 'Documentary', '$5,591', None),
#  ('171', 'Figlia mia', 2019, 'Drama', '$5,447', None),
#  ('172', 'Wildlife', 2019, 'Drama', '$5,329', None),
#  ('173', 'Ramen Teh', 2019, 'Drama', '$5,303', None),
#  ('174', 'Tito e os PÃ¡ssaros', 2019, 'Adventure', '$4,332', None),
#  ('175', 'Sicilian Ghost Story', 2019, 'Drama', '$3,935', None),
#  ('176',
#   'Frantz Fanon: Black Skin, White Mask',
#   2019,
#   'Documentary',
#   '$3,827',
#   None),
#  ('177', 'Ce magnifique gÃ¢teau!', 2019, 'GKIDS', '$3,503', None),
#  ('178', 'Un Traductor', 2019, 'Drama', '$3,278', None),
#  ('179', 'Filmworker', 2019, 'Documentary', '$3,016', None),
#  ('180', 'Der Himmel Ã¼ber Berlin', 2019, 'Drama', '$3,004', None),
#  ('181', 'Bedoune Tarikh, Bedoune Emza', 2019, 'Drama', '$2,567', None),
#  ('182', 'Der Mann aus dem Eis', 2019, 'Thriller/Suspense', '$2,118', None),
#  ('183', 'Salafists', 2019, 'Documentary', '$1,939', None),
#  ('184', 'Detour', 2019, 'Drama', '$1,540', None),
#  ('185', 'State Like Sleep', 2019, 'Drama', '$1,469', None),
#  ('186', 'The Hours and Times', 2019, 'Drama', '$1,273', None),
#  ('187', 'Narcissister Organ Player', 2019, 'Documentary', '$1,015', None),
#  ('188', 'Chef Flynn', 2019, 'Documentary', '$721', None),
#  ('189', 'I am Not a Witch', 2019, 'Drama', '$550', None),
#  ('190',
#   'Divide and Conquer: The Story of Roger Ailes',
#   2019,
#   'Documentary',
#   '$474',
#   None)]

# %%
year_movies.keys()
# Out:
# dict_keys([2019, 2018, 2017, 2016, 2015])

# %%
#creates a dataframe with the movie dictionary
def create_frame(year_movies):
    rank = []
    title = []
    year = []
    genre = []
    gross = []
    budget = []
    #turn dict into list
    for movie_lst in year_movies.values():
        #go through each movie in the list
        for movie in movie_lst:
            rank.append(movie[0])
            title.append(movie[1])
            year.append(movie[2])
            genre.append(movie[3])
            gross.append(movie[4])
            budget.append(movie[5])
            
    #create dataframe
    df = pd.DataFrame({'rank_in_year': rank,
                       'title': title,
                       'year': year,
                       'genre': genre,
                       'gross': gross,
                       'budget': budget})
    #returns movie dataframe
    return df

df = create_frame(year_movies)

# %%
df
# Out:
#      rank_in_year                                              title  year  \
# 0               1                                     Captain Marvel  2019
# 1               2         How to Train Your Dragon: The Hidden World  2019
# 2               3                                              Glass  2019
# 3               4                                         The Upside  2019
# 4               5                  The LEGO Movie 2: The Second Part  2019
# 5               6                                                 Us  2019
# 6               7                                Alita: Battle Angel  2019
# 7               8                                            Aquaman  2019
# 8               9               Tyler Perry's A Madea Family Funeral  2019
# 9              10               Spider-Man: Into The Spider-Verse 3D  2019
# 10             11                                          Bumblebee  2019
# 11             12                                      What Men Want  2019
# 12             13                                         Green Book  2019
# 13             14                                  Isn't it Romantic  2019
# 14             15                                   A Dog's Way Home  2019
# 15             16                                           The Mule  2019
# 16             17                                        Escape Room  2019
# 17             18                               Mary Poppins Returns  2019
# 18             19                                       Cold Pursuit  2019
# 19             20                           Dragon Ball Super: Broly  2019
# 20             21                                        Wonder Park  2019
# 21             22                                    Five Feet Apart  2019
# 22             23                                 Happy Death Day 2U  2019
# 23             24                                  Bohemian Rhapsody  2019
# 24             25                            Fighting With My Family  2019
# 25             26                                On the Basis of Sex  2019
# 26             27                                      The Favourite  2019
# 27             28                                               Vice  2019
# 28             29                          The Kid Who Would Be King  2019
# 29             30                                          Miss Bala  2019
# ...           ...                                                ...   ...
# 2160          471                                               Eden  2015
# 2161          472                                   National Gallery  2015
# 2162          473                                     E gun tian shi  2015
# 2163          474                               Hua Li Shang Ban Zou  2015
# 2164          475  Drunk Stoned Brilliant Dead The Story of the N...  2015
# 2165          476                                           Only You  2015
# 2166          477                      Dark Star: H.R. Giger's World  2015
# 2167          478                                    Bande de filles  2015
# 2168          479                                        The Pyramid  2015
# 2169          480                                            GÃ¼eros  2015
# 2170          481                                            Cooties  2015
# 2171          482                                       I Smile Back  2015
# 2172          483                                              Jauja  2015
# 2173          484                          Du rififi chez les hommes  2015
# 2174          485   Brian Wilson: I Just Wasn't Made for These Times  2015
# 2175          486                               The Duke of Burgundy  2015
# 2176          487                                          The Judge  2015
# 2177          488                          Antarctica: A Year on Ice  2015
# 2178          489                           Die geliebten Schwestern  2015
# 2179          490                                  Beyond the Lights  2015
# 2180          491                                      Shao nian ban  2015
# 2181          492                                              Aloft  2015
# 2182          493                          The Quay Brothers in 35MM  2015
# 2183          494                                             Loreak  2015
# 2184          495                                 We Come as Friends  2015
# 2185          496                          The Yes Men Are Revolting  2015
# 2186          497                                              Heist  2015
# 2187          498                                             Spring  2015
# 2188          499                                             Difret  2015
# 2189          500                                        Red Herring  2015
#
#                   genre         gross        budget
# 0                Action  $323,646,033  $152,000,000
# 1             Adventure  $147,460,290  $129,000,000
# 2     Thriller/Suspense  $110,861,630   $20,000,000
# 3                Comedy  $106,984,792   $37,500,000
# 4             Adventure  $103,762,494   $99,000,000
# 5     Thriller/Suspense   $85,106,185   $24,600,000
# 6                Action   $83,956,461          None
# 7                Action   $74,802,530  $160,000,000
# 8                Comedy   $66,688,573          None
# 9             Adventure   $55,923,345   $90,000,000
# 10            Adventure   $55,769,470  $102,000,000
# 11               Comedy   $54,085,444   $20,000,000
# 12               Comedy   $48,837,730   $28,900,000
# 13      Romantic Comedy   $47,691,683   $31,000,000
# 14                Drama   $41,952,715          None
# 15                Drama   $39,084,073   $50,000,000
# 16    Thriller/Suspense   $38,467,985          None
# 17              Musical   $33,014,229  $130,000,000
# 18    Thriller/Suspense   $31,854,994          None
# 19               Action   $30,376,755    $8,500,000
# 20            Adventure   $30,049,734  $100,000,000
# 21                Drama   $28,145,448    $7,000,000
# 22    Thriller/Suspense   $27,892,355    $9,000,000
# 23                Drama   $26,143,592   $55,000,000
# 24               Comedy   $22,028,635   $11,000,000
# 25                Drama   $20,914,838   $20,000,000
# 26         Black Comedy   $18,267,686   $15,000,000
# 27         Black Comedy   $18,093,238   $60,000,000
# 28            Adventure   $16,780,002   $59,000,000
# 29               Action   $14,998,027   $15,000,000
# ...                 ...           ...           ...
# 2160              Drama       $65,460          None
# 2161        Documentary       $64,597          None
# 2162             Comedy       $64,470          None
# 2163            Musical       $63,029          None
# 2164        Documentary       $62,684          None
# 2165    Romantic Comedy       $61,565          None
# 2166        Documentary       $61,303          None
# 2167              Drama       $60,765          None
# 2168             Horror       $60,598          None
# 2169             Comedy       $60,171          None
# 2170       Black Comedy       $60,058          None
# 2171              Drama       $58,738          None
# 2172              Drama       $58,403          None
# 2173  Thriller/Suspense       $57,749          None
# 2174        Documentary       $56,744          None
# 2175              Drama       $56,657          None
# 2176              Drama       $56,282   $50,000,000
# 2177        Documentary       $54,710    $1,000,000
# 2178              Drama       $54,064          None
# 2179              Drama       $54,018    $7,000,000
# 2180             Comedy       $53,252          None
# 2181              Drama       $53,086    $8,000,000
# 2182        Documentary       $51,858          None
# 2183              Drama       $51,238          None
# 2184        Documentary       $50,921          None
# 2185        Documentary       $50,190          None
# 2186  Thriller/Suspense       $50,136    $8,900,000
# 2187             Horror       $49,970          None
# 2188              Drama       $49,667          None
# 2189              Drama       $49,480          None
#
# [2190 rows x 6 columns]

# %%
#Website = the_numbers - turn movie info from dataframe to csv
#df.to_csv("the_numbers_scrap.csv", index=False)
